# %%
import numpy as np
import pandas as pd

# %%
file_1 = pd.read_csv('data1_cleaned.csv')
file_2 = pd.read_csv('data2_cleaned.csv')
file_3 = pd.read_csv('data3_cleaned.csv')
file_4 = pd.read_csv('data4_cleaned.csv')

# %%
file_1.head(2)
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
#
#   order_status          brand product_line product_class product_size  \
# 0     Approved          Solex     Standard        medium       medium
# 1     Approved  Trek Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# 0       71.49          53.62                  41245.0
# 1     2091.47         388.92                  41701.0

# %%
file_2.head(2)
# Out:
#   first_name last_name gender  past_3_years_bike_related_purchases  \
# 0    Chickie   Brister   Male                                   86
# 1      Morly    Genery   Male                                   69
#
#           DOB            job_title job_industry_category wealth_segment  \
# 0  1957-07-12      General Manager         Manufacturing  Mass Customer
# 1  1970-03-22  Structural Engineer              Property  Mass Customer
#
#   deceased_indicator owns_car  tenure            address  postcode state  \
# 0                  N      Yes      14   45 Shopko Center      4500   QLD
# 1                  N       No      16  14 Mccormick Park      2113   NSW
#
#      country  property_valuation  Rank    Value
# 0  Australia                   6     1  1.71875
# 1  Australia                  11     1  1.71875

# %%
file_3.head(2)
# Out:
#    customer_id first_name  last_name  gender  \
# 0            1    Laraine  Medendorp  Female
# 1            2        Eli    Bockman    Male
#
#    past_3_years_bike_related_purchases         DOB               job_title  \
# 0                                   93  1953-10-12     Executive Secretary
# 1                                   81  1980-12-16  Administrative Officer
#
#   job_industry_category wealth_segment deceased_indicator owns_car  tenure
# 0                Health  Mass Customer                  N      Yes    11.0
# 1    Financial Services  Mass Customer                  N      Yes    16.0

# %%
file_4.head(2)
# Out:
#    customer_id              address  postcode state    country  \
# 0            1   060 Morning Avenue      2016   NSW  Australia
# 1            2  6 Meadow Vale Court      2153   NSW  Australia
#
#    property_valuation
# 0                  10
# 1                  10

# %%
file_1_3 = pd.merge(file_1, file_3, on = ['customer_id'])
file_1_3_4 = pd.merge(file_1_3,file_4, on = ['customer_id'])

# %%
file_1_3_4.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1           11065           1         2950       2017-10-16           0.0
# 2           18923          62         2950       2017-04-26           0.0
# 3               2           3         3120       2017-05-21           1.0
# 4            6862           4         3120       2017-10-05           0.0
#
#   order_status           brand product_line product_class product_size  ...  \
# 0     Approved           Solex     Standard        medium       medium  ...
# 1     Approved  Giant Bicycles     Standard        medium       medium  ...
# 2     Approved           Solex     Standard        medium       medium  ...
# 3     Approved   Trek Bicycles     Standard        medium        large  ...
# 4     Approved  Giant Bicycles     Standard          high       medium  ...
#
# ...

# %%
file_1_3_4.to_csv('merged.csv', index=False, encoding='utf-8-sig')

# %%
df = file_1_3_4.sort_values(by=['customer_id'])

# %%
df.head()
# Out:
#      transaction_id  product_id  customer_id transaction_date  online_order  \
# 605           14486          23            1       2017-03-27           0.0
# 608           16423           9            1       2017-12-09           1.0
# 607           15663          32            1       2017-06-04           1.0
# 606           14931          31            1       2017-12-14           1.0
# 599              94          86            1       2017-12-23           0.0
#
#     order_status           brand product_line product_class product_size  ...  \
# 605     Approved  Norco Bicycles     Mountain           low        small  ...
# 608     Approved      OHM Cycles         Road        medium       medium  ...
# 607     Approved  Giant Bicycles     Standard        medium       medium  ...
# 606     Approved  Giant Bicycles     Standard        medium       medium  ...
# 599     Approved      OHM Cycles     Standard        medium       medium  ...
#
# ...

# %%
df.shape
# Out:
# (19968, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19968 entries, 605 to 11299
# Data columns (total 29 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   transaction_id                       19968 non-null  int64
#  1   product_id                           19968 non-null  int64
#  2   customer_id                          19968 non-null  int64
#  3   transaction_date                     19968 non-null  object
#  4   online_order                         19968 non-null  float64
#  5   order_status                         19968 non-null  object
#  6   brand                                19968 non-null  object
#  7   product_line                         19968 non-null  object
#  8   product_class                        19968 non-null  object
#  9   product_size                         19968 non-null  object
#  10  list_price                           19968 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# transaction_id                           0
# product_id                               0
# customer_id                              0
# transaction_date                         0
# online_order                             0
# order_status                             0
# brand                                    0
# product_line                             0
# product_class                            0
# product_size                             0
# list_price                               0
# standard_cost                          174
# product_first_sold_date                  0
# first_name                               0
# last_name                              642
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                    446
# job_title                                0
# job_industry_category                    0
# wealth_segment                           0
# deceased_indicator                       0
# ...

# %%
df.head(3)
# Out:
#      transaction_id  product_id  customer_id transaction_date  online_order  \
# 605           14486          23            1       2017-03-27           0.0
# 608           16423           9            1       2017-12-09           1.0
# 607           15663          32            1       2017-06-04           1.0
#
#     order_status           brand product_line product_class product_size  ...  \
# 605     Approved  Norco Bicycles     Mountain           low        small  ...
# 608     Approved      OHM Cycles         Road        medium       medium  ...
# 607     Approved  Giant Bicycles     Standard        medium       medium  ...
#
#      job_industry_category  wealth_segment  deceased_indicator owns_car  \
# 605                 Health   Mass Customer                   N      Yes
# 608                 Health   Mass Customer                   N      Yes
# 607                 Health   Mass Customer                   N      Yes
#
# ...

# %%
df['transaction_date'] = pd.to_datetime(df.transaction_date, format = '%Y/%m/%d')
df.head(3)
# Out:
#      transaction_id  product_id  customer_id transaction_date  online_order  \
# 605           14486          23            1       2017-03-27           0.0
# 608           16423           9            1       2017-12-09           1.0
# 607           15663          32            1       2017-06-04           1.0
#
#     order_status           brand product_line product_class product_size  ...  \
# 605     Approved  Norco Bicycles     Mountain           low        small  ...
# 608     Approved      OHM Cycles         Road        medium       medium  ...
# 607     Approved  Giant Bicycles     Standard        medium       medium  ...
#
#      job_industry_category  wealth_segment  deceased_indicator owns_car  \
# 605                 Health   Mass Customer                   N      Yes
# 608                 Health   Mass Customer                   N      Yes
# 607                 Health   Mass Customer                   N      Yes
#
# ...

# %%
df['country'].unique()
# Out:
# array(['Australia'], dtype=object)

# %%
df['state'].unique()
# Out:
# array(['NSW', 'QLD', 'VIC'], dtype=object)

# %%
df['state'].value_counts()
# Out:
# NSW    10685
# VIC     5021
# QLD     4262
# Name: state, dtype: int64

# %%
recency_aus = df.groupby(['customer_id'], as_index = False)['transaction_date'].max()
recency_aus.columns = ['customer_id', 'LastPurchaseDate']
recency_aus.head()
# Out:
#    customer_id LastPurchaseDate
# 0            1       2017-12-23
# 1            2       2017-08-24
# 2            4       2017-06-18
# 3            5       2017-12-14
# 4            6       2017-10-27

# %%
recent_date = recency_aus['LastPurchaseDate'].max()

# %%
recency_aus['recency'] = recency_aus['LastPurchaseDate'].apply(lambda x: (recent_date - x).days)
recency_aus.head()
# Out:
#    customer_id LastPurchaseDate  recency
# 0            1       2017-12-23        7
# 1            2       2017-08-24      128
# 2            4       2017-06-18      195
# 3            5       2017-12-14       16
# 4            6       2017-10-27       64

# %% [markdown]
# ### Frequency

# %%
df.head(2)
# Out:
#      transaction_id  product_id  customer_id transaction_date  online_order  \
# 605           14486          23            1       2017-03-27           0.0
# 608           16423           9            1       2017-12-09           1.0
#
#     order_status           brand product_line product_class product_size  ...  \
# 605     Approved  Norco Bicycles     Mountain           low        small  ...
# 608     Approved      OHM Cycles         Road        medium       medium  ...
#
#      job_industry_category  wealth_segment  deceased_indicator owns_car  \
# 605                 Health   Mass Customer                   N      Yes
# 608                 Health   Mass Customer                   N      Yes
#
#     tenure             address  postcode state    country property_valuation
# 605   11.0  060 Morning Avenue      2016   NSW  Australia                 10
# 608   11.0  060 Morning Avenue      2016   NSW  Australia                 10
#
# [2 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
#        'property_valuation'],
#       dtype='object')

# %%
df['past_3_years_bike_related_purchases']
# Out:
# 605      93
# 608      93
# 607      93
# 606      93
# 599      93
#          ..
# 11295    71
# 11294    71
# 11298    71
# 11297    71
# 11299    71
# Name: past_3_years_bike_related_purchases, Length: 19968, dtype: int64

# %%
freq = df.groupby('customer_id')['past_3_years_bike_related_purchases'].count()
aus_freq = pd.DataFrame(freq).reset_index()
aus_freq.columns = ['customer_id', 'Frequency']
aus_freq.head()
# Out:
#    customer_id  Frequency
# 0            1         11
# 1            2          3
# 2            4          2
# 3            5          6
# 4            6          5

# %%
group_df = df.groupby('customer_id')
group_df.size()
# Out:
# customer_id
# 1       11
# 2        3
# 4        2
# 5        6
# 6        5
#         ..
# 3496     4
# 3497     3
# 3498     6
# 3499     7
# 3500     6
# Length: 3489, dtype: int64

# %%
aus_rec_freq = recency_aus.merge(aus_freq, on = 'customer_id').drop(columns = 'LastPurchaseDate')
aus_rec_freq.head()
# Out:
#    customer_id  recency  Frequency
# 0            1        7         11
# 1            2      128          3
# 2            4      195          2
# 3            5       16          6
# 4            6       64          5

# %% [markdown]
# ### Monetary value

# %%
df.head(2)
# Out:
#      transaction_id  product_id  customer_id transaction_date  online_order  \
# 605           14486          23            1       2017-03-27           0.0
# 608           16423           9            1       2017-12-09           1.0
#
#     order_status           brand product_line product_class product_size  ...  \
# 605     Approved  Norco Bicycles     Mountain           low        small  ...
# 608     Approved      OHM Cycles         Road        medium       medium  ...
#
#      job_industry_category  wealth_segment  deceased_indicator owns_car  \
# 605                 Health   Mass Customer                   N      Yes
# 608                 Health   Mass Customer                   N      Yes
#
#     tenure             address  postcode state    country property_valuation
# 605   11.0  060 Morning Avenue      2016   NSW  Australia                 10
# 608   11.0  060 Morning Avenue      2016   NSW  Australia                 10
#
# [2 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
#        'property_valuation'],
#       dtype='object')

# %%
df['list_price']
# Out:
# 605       688.63
# 608       742.54
# 607       642.70
# 606       230.91
# 599       235.63
#           ...
# 11295     792.90
# 11294      71.49
# 11298      60.34
# 11297    1311.44
# 11299    1458.17
# Name: list_price, Length: 19968, dtype: float64

# %%
m = df.groupby('customer_id')['list_price'].sum()
m = pd.DataFrame(m).reset_index()
m.columns = ['customer_id', 'Monetary_value']
m.head()
# Out:
#    customer_id  Monetary_value
# 0            1         9084.45
# 1            2         4149.07
# 2            4         1047.72
# 3            5         5903.20
# 4            6         5931.69

# %%
aus_full_rfm = aus_rec_freq.merge(m, on = 'customer_id')
aus_full_rfm.head()
# Out:
#    customer_id  recency  Frequency  Monetary_value
# 0            1        7         11         9084.45
# 1            2      128          3         4149.07
# 2            4      195          2         1047.72
# 3            5       16          6         5903.20
# 4            6       64          5         5931.69

# %%
import matplotlib.pyplot as plt
import seaborn as sns

list1 = ['recency', 'Frequency', 'Monetary_value']
for i in list1:
    print(str(i) + ':')
    ax = sns.boxplot(x = aus_full_rfm[str(i)])
    plt.show()
# Out:
# recency:
# Frequency:
# Monetary_value:

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
list1 = ['recency', 'Frequency', 'Monetary_value']
for col in list1:
    sns.displot(aus_full_rfm[col])
    ax.set_title('Distribution of %s' % col)
    plt.show()

# %%
quantiles = aus_full_rfm.quantile(q = [0.25, 0.5, 0.75])
quantiles
# Out:
#       customer_id  recency  Frequency  Monetary_value
# 0.25        879.0     17.0        4.0         4197.33
# 0.50       1752.0     44.0        6.0         6021.83
# 0.75       2625.0     85.0        7.0         8203.29

# %%
quantiles.to_dict()
# Out:
# {'customer_id': {0.25: 879.0, 0.5: 1752.0, 0.75: 2625.0},
#  'recency': {0.25: 17.0, 0.5: 44.0, 0.75: 85.0},
#  'Frequency': {0.25: 4.0, 0.5: 6.0, 0.75: 7.0},
#  'Monetary_value': {0.25: 4197.33, 0.5: 6021.83, 0.75: 8203.289999999999}}

# %%
def rec_score(x, m, d): # x->value, m->recency/ frequency/ monetary_value, d->quartile dict
    if x <= d[m][0.25]:
        return 4
    elif x <= d[m][0.5]:
        return 3
    elif x <= d[m][0.75]:
        return 2
    else:
        return 1

def f_m_score(x, m, d):
    if x <= d[m][0.25]:
        return 1
    elif x <= d[m][0.5]:
        return 2
    elif x <= d[m][0.75]:
        return 3
    else:
        return 4
    
    
rfm_seg = aus_full_rfm
rfm_seg['R_Quartile'] = rfm_seg['recency'].apply(rec_score, args = ('recency', quantiles,))
rfm_seg['F_Quartile'] = rfm_seg['Frequency'].apply(rec_score, args = ('Frequency', quantiles,))
rfm_seg['M_Quartile'] = rfm_seg['Monetary_value'].apply(rec_score, args = ('Monetary_value', quantiles,))
rfm_seg.head()
# Out:
#    customer_id  recency  Frequency  Monetary_value  R_Quartile  F_Quartile  \
# 0            1        7         11         9084.45           4           1
# 1            2      128          3         4149.07           1           4
# 2            4      195          2         1047.72           1           4
# 3            5       16          6         5903.20           4           3
# 4            6       64          5         5931.69           2           3
#
#    M_Quartile
# 0           1
# 1           4
# 2           4
# 3           3
# 4           3

# %%
rfm_seg['RFM_Score'] = rfm_seg['R_Quartile'].map(str) +\
                       rfm_seg['F_Quartile'].map(str) +\
                       rfm_seg['M_Quartile'].map(str)
rfm_seg.head()
# Out:
#    customer_id  recency  Frequency  Monetary_value  R_Quartile  F_Quartile  \
# 0            1        7         11         9084.45           4           1
# 1            2      128          3         4149.07           1           4
# 2            4      195          2         1047.72           1           4
# 3            5       16          6         5903.20           4           3
# 4            6       64          5         5931.69           2           3
#
#    M_Quartile RFM_Score
# 0           1       411
# 1           4       144
# 2           4       144
# 3           3       433
# 4           3       233

# %%
rfm_seg.shape
# Out:
# (3489, 8)

# %%
rfm_seg.to_csv('rfm_merged_1.csv', index=False, encoding='utf-8-sig')

# %%
df_merge_11 = pd.read_csv(r"C:\Users\User\KPMG\rfm_merged_1.csv")
df_merge_11
# Out:
#       customer_id  recency  Frequency  Monetary_value  R_Quartile  F_Quartile  \
# 0               1        7         11         9084.45           4           1
# 1               2      128          3         4149.07           1           4
# 2               4      195          2         1047.72           1           4
# 3               5       16          6         5903.20           4           3
# 4               6       64          5         5931.69           2           3
# ...           ...      ...        ...             ...         ...         ...
# 3484         3496      256          4         4725.38           1           4
# 3485         3497       52          3         3744.07           2           4
# 3486         3498      127          6         5177.06           1           3
# 3487         3499       51          7         7673.48           2           2
# 3488         3500      144          6         4922.41           1           3
#
#       M_Quartile  RFM_Score
# ...

# %%
rfm_seg[rfm_seg.RFM_Score == '444'].sort_values('Monetary_value', ascending = False).head()
# Out:
#       customer_id  recency  Frequency  Monetary_value  R_Quartile  F_Quartile  \
# 2748         2758       15          4         4188.40           4           4
# 2763         2773        4          4         4179.19           4           4
# 2034         2042       11          3         4170.51           4           4
# 1154         1161       12          4         4151.98           4           4
# 554           559        6          4         4129.68           4           4
#
#       M_Quartile RFM_Score
# 2748           4       444
# 2763           4       444
# 2034           4       444
# 1154           4       444
# 554            4       444

# %%
rfm_seg[rfm_seg.RFM_Score == '444'].shape
# Out:
# (114, 8)

# %%
rfm_seg[rfm_seg.RFM_Score == '111'].sort_values('Monetary_value', ascending = False).tail()
# Out:
#       customer_id  recency  Frequency  Monetary_value  R_Quartile  F_Quartile  \
# 3405         3417       95          8         8566.05           1           1
# 2601         2610      112          8         8499.22           1           1
# 1170         1177       87          8         8367.47           1           1
# 2600         2609      181          8         8362.17           1           1
# 917           924      109          9         8254.23           1           1
#
#       M_Quartile RFM_Score
# 3405           1       111
# 2601           1       111
# 1170           1       111
# 2600           1       111
# 917            1       111

# %%
print('Best Customers:', len(rfm_seg[rfm_seg['RFM_Score'] == '444']))
print('Loyal Customers:', (len(rfm_seg[rfm_seg['RFM_Score'] == '344'])+len(rfm_seg[rfm_seg['RFM_Score'] == '333'])))
print('Promising Customers:', (len(rfm_seg[rfm_seg['RFM_Score'] == '424'])+len(rfm_seg[rfm_seg['RFM_Score'] == '434'])))
#print('Large Spending Customers:', len(rfm_seg[rfm_seg['M_Quartile'] == 4]))
#print('Potential:', len(rfm_seg[rfm_seg['RFM_Score'] == '434']))
print('Need Attention:', (len(rfm_seg[rfm_seg['RFM_Score'] == '334'])+len(rfm_seg[rfm_seg['RFM_Score'] == '434'])) 
      +(len(rfm_seg[rfm_seg['RFM_Score'] == '443'])))
print('Can not lose:', len(rfm_seg[rfm_seg['RFM_Score'] == '144']))
print('Risk Customers:', (len(rfm_seg[rfm_seg['RFM_Score'] == '224'])+len(rfm_seg[rfm_seg['RFM_Score'] == '124'])))
print('Loss Cheap Customers:', len(rfm_seg[rfm_seg['RFM_Score'] == '111']))
# Out:
# Best Customers: 114
# Loyal Customers: 253
# Promising Customers: 31
# Need Attention: 131
# Can not lose: 337
# Risk Customers: 4
# Loss Cheap Customers: 39

# %% [markdown]
# ### kmeans

# %%
import seaborn as sns
import matplotlib.pyplot as plt

list2 = ['recency', 'Frequency', 'Monetary_value']
for i in list2:
    print(str(i) + ':')
    ax = sns.boxplot(x = aus_full_rfm[str(i)])
    plt.show()
# Out:
# recency:
# Frequency:
# Monetary_value:

# %%
from scipy import stats
# remove the customer id column
new_df = aus_full_rfm[['recency', 'Frequency', 'Monetary_value']]
# remove outliers
z_scores = stats.zscore(new_df)
abs_z_scores = np.abs(z_scores)
filtered_entries = (abs_z_scores < 3).all(axis=1)
new_df = new_df[filtered_entries]
new_df
# Out:
#       recency  Frequency  Monetary_value
# 0           7         11         9084.45
# 1         128          3         4149.07
# 2         195          2         1047.72
# 3          16          6         5903.20
# 4          64          5         5931.69
# ...       ...        ...             ...
# 3483       13          7         8626.65
# 3485       52          3         3744.07
# 3486      127          6         5177.06
# 3487       51          7         7673.48
# 3488      144          6         4922.41
#
# [3400 rows x 3 columns]

# %%
# standardization
from sklearn.preprocessing import StandardScaler
new_df = new_df.drop_duplicates()
col_names = ['recency', 'Frequency', 'Monetary_value']
features = new_df[col_names]
scaler = StandardScaler().fit(features.values)
features = scaler.transform(features.values)
scaled_features = pd.DataFrame(features, columns = col_names)
scaled_features
# Out:
#        recency  Frequency  Monetary_value
# 0    -0.993782   2.370684        0.970876
# 1     1.399233  -1.225468       -0.770781
# 2     2.724291  -1.674987       -1.865223
# 3    -0.815789   0.123089       -0.151762
# 4     0.133506  -0.326430       -0.141708
# ...        ...        ...             ...
# 3395 -0.875120   0.572608        0.809322
# 3396 -0.103818  -1.225468       -0.913702
# 3397  1.379456   0.123089       -0.408011
# 3398 -0.123594   0.572608        0.472956
# 3399  1.715665   0.123089       -0.497875
#
# [3400 rows x 3 columns]

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import  Axes3D
SSE = []
for cluster in range(1, 10):
    kmeans = KMeans(n_clusters = cluster, init='k-means++')
    kmeans.fit(scaled_features)
    SSE.append(kmeans.inertia_)
    
frame = pd.DataFrame({'Cluster':range(1,10), 'SSE':SSE})
plt.plot(frame['Cluster'], frame['SSE'], marker = 'o')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
# Out:
# Text(0, 0.5, 'Inertia')

# %%
kmeans =KMeans(n_clusters = 4, init = 'k-means++')
kmeans.fit(scaled_features)
# Out:
# KMeans(n_clusters=4)

# %%
pred = kmeans.predict(scaled_features)
frame = pd.DataFrame(new_df)
frame['cluster'] = pred
frame
# Out:
#       recency  Frequency  Monetary_value  cluster
# 0           7         11         9084.45        3
# 1         128          3         4149.07        2
# 2         195          2         1047.72        2
# 3          16          6         5903.20        0
# 4          64          5         5931.69        0
# ...       ...        ...             ...      ...
# 3483       13          7         8626.65        0
# 3485       52          3         3744.07        1
# 3486      127          6         5177.06        2
# 3487       51          7         7673.48        0
# 3488      144          6         4922.41        2
#
# [3400 rows x 4 columns]

# %%
avg_df = frame.groupby(['cluster'], as_index = False).mean()
for i in list2:
    sns.barplot(x='cluster', y=str(i), data=avg_df)
    plt.show()

# %%
rfm_seg.head()
# Out:
#    customer_id  recency  Frequency  Monetary_value  R_Quartile  F_Quartile  \
# 0            1        7         11         9084.45           4           1
# 1            2      128          3         4149.07           1           4
# 2            4      195          2         1047.72           1           4
# 3            5       16          6         5903.20           4           3
# 4            6       64          5         5931.69           2           3
#
#    M_Quartile RFM_Score
# 0           1       411
# 1           4       144
# 2           4       144
# 3           3       433
# 4           3       233

# %%
rfm_merge = pd.read_csv(r"C:\Users\User\KPMG\rfm_merged.csv")
rfm_merge
# Out:
#       CustomerID  recency  Frequency  Monetary_value  R_Quartile  F_Quartile  \
# 0              1        7         11         9084.45           4           1
# 1              2      128          3         4149.07           1           4
# 2              4      195          2         1047.72           1           4
# 3              5       16          6         5903.20           4           3
# 4              6       64          5         5931.69           2           3
# ...          ...      ...        ...             ...         ...         ...
# 3484        3496      256          4         4725.38           1           4
# 3485        3497       52          3         3744.07           2           4
# 3486        3498      127          6         5177.06           1           3
# 3487        3499       51          7         7673.48           2           2
# 3488        3500      144          6         4922.41           1           3
#
#       M_Quartile  RFM_Score
# ...

# %%
df
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 605             14486          23            1       2017-03-27           0.0
# 608             16423           9            1       2017-12-09           1.0
# 607             15663          32            1       2017-06-04           1.0
# 606             14931          31            1       2017-12-14           1.0
# 599                94          86            1       2017-12-23           0.0
# ...               ...         ...          ...              ...           ...
# 11295            6309          69         3500       2017-01-09           1.0
# 11294            2463           2         3500       2017-04-25           0.0
# 11298           14870          22         3500       2017-01-11           0.0
# 11297            8562          33         3500       2017-08-08           0.0
# 11299           19836          40         3500       2017-03-14           1.0
#
# ...

# %%
final_rfm_merge = pd.merge(df_merge_11, df, on = ['customer_id'])
final_rfm_merge.shape
# Out:
# (19968, 36)

# %%
final_rfm_merge.to_csv('all_final_1.csv', index=False, encoding='utf-8-sig')
